# %%
#PC DIRECTORY - RUN BEFORE MAKING IMAGES

import sys
sys.path.append("/Users/macoz/Desktop/Research/Sarah/Jupiter_Notebooks/") 
import matplotlib as plt2 #need this for patches for shaded circles
import numpy as np
import matplotlib.pyplot as plt
import gizmo_analysis as gizmo 
import utilities as ut
import matplotlib.colors as colors
from matplotlib import rc #to use Latex math symbols like 'phi'
import astropy
from astropy.io import ascii
import matplotlib
import pdb
from importlib import reload
#from sl_utilities import distance_functions
#pdb.set_trace()  #<--in case need to troubleshoot
import pickle
dirname_gmc = '/Users/macoz/Desktop/Research/Sarah/Jupiter_Notebooks/' #change this! 
filename_gmc = 'cloud_props_m12m_mhd_stamp_fire2650.txt'
data_gmc  = astropy.io.ascii.read(dirname_gmc+filename_gmc) #data_gmc.keys() #to see content

# %%
simulation_directory = '/Users/macoz/Desktop/Research/Sarah/Jupiter_Notebooks/sims/m12i_res7100'

# %%
#MACBOOK DIRECTORY - RUN BEFORE MAKING IMAGES

import sys
sys.path.append("") 
import matplotlib as plt2 #need this for patches for shaded circles
import numpy as np
import matplotlib.pyplot as plt
import gizmo_analysis as gizmo 
import utilities as ut
import matplotlib.colors as colors
from matplotlib import rc #to use Latex math symbols like 'phi'
import astropy
from astropy.io import ascii
import matplotlib
import pdb
from importlib import reload
#from sl_utilities import distance_functions
#pdb.set_trace()  #<--in case need to troubleshoot
import pickle
dirname_gmc = '' #change this! 
filename_gmc = 'cloud_props_m12m_mhd_stamp_fire2650.txt'
data_gmc  = astropy.io.ascii.read(dirname_gmc+filename_gmc) #data_gmc.keys() #to see content

# %%
simulation_directory = ''

# %%
part = gizmo.io.Read.read_snapshots(['star', 'gas'], 'redshift', 0, simulation_directory)
# Out:
# # in utilities.simulation.Snapshot():
# * reading:  Users/macoz/Research/Research/Sarah/Jupiter_Notebooks/sims/m12i_res7100/snapshot_times.txt
#
# * input redshift = 0:  using snapshot index = 600, redshift = 0.000
#
#
# # in gizmo_analysis.gizmo_io.Read():
# * reading header from:  Users/macoz/Research/Research/Sarah/Jupiter_Notebooks/sims/m12i_res7100/output\snapshot_600\snapshot_600.0.hdf5
#   snapshot contains the following number of particles:
#     dark      (id = 1): 70514272 particles
#     dark2     (id = 2): 5513331 particles
#     gas       (id = 0): 57060074 particles
#     star      (id = 4): 13976485 particles
#     blackhole (id = 5): 0 particles
#
# * reading the following
#   species: ['star', 'gas']
#
# * reading particles from:
#     output\snapshot_600\snapshot_600.0.hdf5
#     output\snapshot_600\snapshot_600.1.hdf5
#     output\snapshot_600\snapshot_600.2.hdf5
#     output\snapshot_600\snapshot_600.3.hdf5
#
# ! cannot find MUSIC config file:  Users/macoz/Research/Research/Sarah/Jupiter_Notebooks/sims/m12i_res7100/*/*.conf
# ! missing cosmological parameters, assuming the following (from AGORA):
#   assuming omega_baryon = 0.0455
#   assuming sigma_8 = 0.807
#   assuming n_s = 0.961
#
# * checking sanity of particle properties
#
#   cannot read file containing hosts coordinates
#   instead will assign hosts via iterative zoom on particle mass
#
# # in utilities.particle.get_center_positions():
# * assigning position for 1 center/host, via iterative zoom-in on star particle mass
#   host1 position = (41792.15, 44131.23, 46267.68) [kpc comoving]
#
# # in utilities.particle.get_center_velocities():
# * assigning velocity for 1 center/host, weighting star particles by mass
#   host1 velocity = (-53.2, 73.4, 95.2) [km / s]

# %%
plt.style.use('default') #makes the background the default python

fig1, ax = plt.subplots() #sets up plot
ax.scatter(part['star'].prop('host.distance')[:,0],
           part['star'].prop('host.distance')[:,1], c="blue", alpha=1, marker=r'.', #says to plot x vs y with the color blue and marker as .
           label="GMC") #calls it gmc in legend
ax.set_xlabel("X (kpc)") #sets x axis label
ax.set_ylabel("Y (kpc)") #sets y axis label

ax.set_aspect('equal') #sets apsect ratio to be equal

#ax.set_xlim([-15, 15]) #sets x limit at -15 to 15
#ax.set_ylim([-15, 15]) #sets y limit at -15 to 15
ax.legend() #sets up legend

#plt.savefig('plot_x_vs_y.pdf') #saves plot as a pdf
#plt.savefig('plot_x_vs_y.png') #saves plot as a png

plt.show() #shows plot

# %%
#code to graph x vs y to help understand it
plt.style.use('default') #makes the background the default python

fig1, ax = plt.subplots() #sets up plot
ax.scatter(part['star'].prop('host.distance')[:,0],
           part['star'].prop('host.distance')[:,2], c="blue", alpha=1, marker=r'.', #says to plot x vs y with the color blue and marker as .
           label="GMC") #calls it gmc in legend
ax.set_xlabel("X (kpc)") #sets x axis label
ax.set_ylabel("Z (kpc)") #sets y axis label

ax.set_aspect('equal') #sets apsect ratio to be equal

#ax.set_xlim([-15, 15]) #sets x limit at -15 to 15
#ax.set_ylim([-15, 15]) #sets y limit at -15 to 15
ax.legend() #sets up legend

#plt.savefig('plot_x_vs_y.pdf') #saves plot as a pdf
#plt.savefig('plot_x_vs_y.png') #saves plot as a png

plt.show() #shows plot

# %%
#code to graph x vs y to help understand it
plt.style.use('default') #makes the background the default python

fig1, ax = plt.subplots() #sets up plot
ax.scatter(part['star'].prop('host.distance')[:,0],
           part['star'].prop('host.distance')[:,2], c="blue", alpha=1, marker=r'.', #says to plot x vs y with the color blue and marker as .
           label="GMC") #calls it gmc in legend
ax.set_xlabel("X (kpc)") #sets x axis label
ax.set_ylabel("Z (kpc)") #sets y axis label

ax.set_aspect('equal') #sets apsect ratio to be equal

ax.set_xlim([-10000, 10000]) #sets x limit at -15 to 15
ax.set_ylim([-10000, 10000]) #sets y limit at -15 to 15
ax.legend() #sets up legend

#plt.savefig('plot_x_vs_y.pdf') #saves plot as a pdf
#plt.savefig('plot_x_vs_y.png') #saves plot as a png

plt.show() #shows plot

# %%
#code to graph x vs y to help understand it
plt.style.use('default') #makes the background the default python

fig1 = plt.figure()
ax = fig1.add_subplot(111, projection='3d') #sets up plot

X = part['star'].prop('host.distance')[:,0]
Y = part['star'].prop('host.distance')[:,1]
Z = part['star'].prop('host.distance')[:,2]

ax.scatter(X,Y,Z, c="blue", alpha=1, marker=r'.', #says to plot x vs y with the color blue and marker as .
           label="Star") #calls it gmc in legend

ax.set_xlabel("X (kpc)") 
ax.set_ylabel("Y (kpc)") 
ax.set_zlabel("Z (kpc)")

ax.set_aspect('equal') #sets apsect ratio to be equal

#ax.set_xlim([-15, 15]) #sets x limit at -15 to 15
#ax.set_ylim([-15, 15]) #sets y limit at -15 to 15
#ax.set_zlim([-15, 15])
ax.legend() #sets up legend

#plt.savefig('plot_x_vs_y.pdf') #saves plot as a pdf
#plt.savefig('plot_x_vs_y.png') #saves plot as a png

plt.show() #shows plot

# %%
#code to graph x vs y to help understand it
plt.style.use('default') #makes the background the default python

fig1 = plt.figure()
ax = fig1.add_subplot(111, projection='3d') #sets up plot

X = part['star'].prop('host.distance')[:,0]
Y = part['star'].prop('host.distance')[:,1]
Z = part['star'].prop('host.distance')[:,2]

ax.scatter(X,Y,Z, c="blue", alpha=1, marker=r'.', #says to plot x vs y with the color blue and marker as .
           label="Star") #calls it gmc in legend

ax.set_xlabel("X (kpc)") 
ax.set_ylabel("Y (kpc)") 
ax.set_zlabel("Z (kpc)")

ax.set_aspect('equal') #sets apsect ratio to be equal

ax.set_xlim([-25000, -7500]) #sets x limit at -15 to 15
ax.set_ylim([13000, 30000]) #sets y limit at -15 to 15
ax.set_zlim([-22500, -5000])
ax.legend() #sets up legend

#plt.savefig('plot_x_vs_y.pdf') #saves plot as a pdf
#plt.savefig('plot_x_vs_y.png') #saves plot as a png

plt.show() #shows plot
