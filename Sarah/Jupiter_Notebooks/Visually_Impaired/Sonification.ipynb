# %%
import matplotlib.pyplot as plt
from astropy.io import ascii
import numpy as np
import pandas as pd

# %%
filename = 'm12i_res7100_mhdcv.disk.ecsv'
table = ascii.read(filename, guess=False)

# %%
mask = (table['age'] < .050) #this checks each entry in the age column of the table, and notes "True" or "False" for entry
veryyoungstars = table[mask]
veryyoung_x = veryyoungstars['x'] +10 
veryyoung_y = veryyoungstars['y'] +10
print(veryyoung_y)
# Out:
#         y
# ------------------
#             10.687
#             10.666
#             10.695
# 10.681000000000001
#             10.677
#             10.678
#             10.644
#             10.631
#             10.539
#             10.526
#                ...
#             12.522
#             12.517
#             12.315
#             12.188
# 12.184000000000001
#             12.258
#             12.235
# 11.725999999999999
#             11.751
#             11.709
#             11.321
# Length = 23240 rows

# %%
plt.style.use('default') #makes the background the default python

fig1, ax = plt.subplots() #sets up plot
ax.scatter(veryyoung_x, veryyoung_y, alpha=1, color = "blue" ,marker=r'.', s= 1, #says to plot x vs y with the color blue and marker as .
           label="Stars") #calls it gmc in legend
ax.set_xlabel("X (kpc)") #sets x axis label
ax.set_ylabel("Y (kpc)") #sets y axis label

ax.set_aspect('equal') #sets apsect ratio to be equal

#ax.set_xlim([-15, 15]) #sets x limit at -15 to 15
#ax.set_ylim([-15, 15]) #sets y limit at -15 to 15
ax.legend() #sets up legend

plt.savefig('plot_x_vs_y.pdf') #saves plot as a pdf
plt.savefig('plot_x_vs_y.png') #saves plot as a png

plt.show() #shows plot

# %%
mask1 = (table['age'] < .050) & ((table['Rcyl'] - table['Rcyl_form']) > -1.5 ) #this checks each entry in the age column of the table, and notes "True" or "False" for entry
veryyoungstars1 = table[mask1]
veryyoung_x1 = veryyoungstars1['x']
veryyoung_y1 = veryyoungstars1['y']

# %%
plt.style.use('default') #makes the background the default python

fig1, ax = plt.subplots() #sets up plot
ax.scatter(veryyoung_x1, veryyoung_y1, alpha=1, color = "blue" ,marker=r'.', s= 1, #says to plot x vs y with the color blue and marker as .
           label="Stars") #calls it gmc in legend
ax.set_xlabel("X (kpc)") #sets x axis label
ax.set_ylabel("Y (kpc)") #sets y axis label

ax.set_aspect('equal') #sets apsect ratio to be equal

#ax.set_xlim([-15, 15]) #sets x limit at -15 to 15
#ax.set_ylim([-15, 15]) #sets y limit at -15 to 15
ax.legend() #sets up legend

plt.savefig('plot_x_vs_y.pdf') #saves plot as a pdf
plt.savefig('plot_x_vs_y.png') #saves plot as a png

plt.show() #shows plot

# %%
mask2 = (table['age'] < .050) & ((table['Rcyl'] - table['Rcyl_form']) < -1.5 ) #this checks each entry in the age column of the table, and notes "True" or "False" for entry
veryyoungstars2 = table[mask2]
veryyoung_x2 = veryyoungstars2['x']
veryyoung_y2 = veryyoungstars2['y']

# %%
plt.style.use('default') #makes the background the default python

fig1, ax = plt.subplots() #sets up plot
ax.scatter(veryyoung_x2, veryyoung_y2, alpha=1, color = "red" ,marker=r'.', s= 1, #says to plot x vs y with the color blue and marker as .
           label="Stars") #calls it gmc in legend
ax.set_xlabel("X (kpc)") #sets x axis label
ax.set_ylabel("Y (kpc)") #sets y axis label

ax.set_aspect('equal') #sets apsect ratio to be equal

#ax.set_xlim([-15, 15]) #sets x limit at -15 to 15
#ax.set_ylim([-15, 15]) #sets y limit at -15 to 15
ax.legend() #sets up legend

plt.savefig('plot_x_vs_y.pdf') #saves plot as a pdf
plt.savefig('plot_x_vs_y.png') #saves plot as a png

plt.show() #shows plot

# %%
#PLOT BOTH
plt.style.use('default') #makes the background the default python

fig1, ax = plt.subplots() #sets up plot
ax.scatter(veryyoung_x1, veryyoung_y1, alpha=1, color = "blue" ,marker=r'.', s= 1, #says to plot x vs y with the color blue and marker as .
           label="Stars") #calls it gmc in legend
ax.scatter(veryyoung_x2, veryyoung_y2, alpha=1, color = "red" ,marker=r'.', s= 1, #says to plot x vs y with the color red and marker as .
           label="Stars that move far from birthplace") #calls it gmc in legend
ax.set_xlabel("X (kpc)") #sets x axis label
ax.set_ylabel("Y (kpc)") #sets y axis label

ax.set_aspect('equal') #sets apsect ratio to be equal

#ax.set_xlim([-15, 15]) #sets x limit at -15 to 15
#ax.set_ylim([-15, 15]) #sets y limit at -15 to 15
ax.legend() #sets up legend

plt.savefig('plot_x_vs_y.pdf') #saves plot as a pdf
plt.savefig('plot_x_vs_y.png') #saves plot as a png

plt.show() #shows plot

# %%
mask0 = (table['age'] < .025)
veryyoungstars0 = table[mask0]
veryyoung_x0 = veryyoungstars0['x'] +10
veryyoung_y0 = veryyoungstars0['y'] +10
n_stars = len(mask0)

mask11 = (table['age'] < .025) & ((table['Rcyl'] - table['Rcyl_form']) > -1.5 )  #this checks each entry in the age column of the table, and notes "True" or "False" for entries that dont move far from birth location
veryyoungstars11 = table[mask]
veryyoung_x11 = veryyoungstars11['x'] +10
veryyoung_y11 = veryyoungstars11['y'] +10


mask22 = (table['age'] < .025) & ((table['Rcyl'] - table['Rcyl_form']) < -1.5 ) #this checks each entry in the age column of the table, and notes "True" or "False" for entry that do move far from birth location
veryyoungstars22 = table[mask2]
veryyoung_x22 = veryyoungstars22['x']+10
veryyoung_y22 = veryyoungstars22['y']+10

#print(veryyoung_x0)
veryyoungstars111 = veryyoungstars11['y']
print(veryyoungstars111)
# Out:
#   y
# -----
# 0.687
# 0.666
# 0.695
# 0.681
# 0.677
# 0.678
# 0.644
# 0.631
# 0.539
# 0.526
#   ...
# 2.522
# 2.517
# 2.315
# 2.188
# 2.184
# 2.258
# 2.235
# 1.726
# 1.751
# 1.709
# 1.321
# Length = 23240 rows

# %%
X_values = veryyoung_x0    #this is a numpy array (not a list), you can do mathematical operations directly on the object
Y_values = veryyoung_y0

times_myrs = X_values  #measure time from oldest crater (first impact) in data

# %%
def map_value(value, min_value, max_value, min_result, max_result):
    '''maps value (or array of values) from one range to another'''
    result = min_result + (value - min_value) / (max_value - min_value) * (max_result - min_result)
    return result

# %%
myrs_per_beat = 25  #number of Myrs for each beat of music 

t_data = times_myrs/myrs_per_beat #rescale time from Myrs to beats


duration_beats = max(t_data)  #duration in beats (actually, onset of last note)
print('Duration:', duration_beats, 'beats')
# Out:
# Duration: 0.79148 beats

# %%
duration_beats = 52.8 #desired duration in beats (actually, onset of last note)

t_data = map_value(times_myrs, 0, max(times_myrs), 0, duration_beats)

#or
#t_data = map_value(ages, min(ages), max(ages), duration_beats, 0)

myrs_per_beat = max(times_myrs)/duration_beats
print('Myrs per beat:', myrs_per_beat)
# Out:
# Myrs per beat: 0.3747537878787879

# %%
#calculate duration in seconds
bpm = 60  #if bpm = 60, 1 beat = 1 sec 
duration_sec = duration_beats*60/bpm #duration in seconds (actually, onset of last note)
print('Duration:', duration_sec, 'seconds')


plt.scatter(t_data, Y_values, s=Y_values)
plt.xlabel('time [beats]')
plt.ylabel('KPC')
ax.set_aspect('equal') #sets apsect ratio to be equal
plt.show()
# Out:
# Duration: 52.8 seconds

# %%
# Assuming Y_values is a pandas DataFrame or a similar structure
# Extract the 'y' column from Y_values
y_data = Y_values

# Normalize y_data to the range [0, 1]
y_min = np.min(y_data)
y_max = np.max(y_data)
y_data_normalized = (y_data - y_min) / (y_max - y_min)

# Ensure y_data_normalized is in the range [0, 1]
y_data_normalized = np.clip(y_data_normalized, 0, 1)

# Apply the scaling to the normalized data
y_scale = 0.5
y_data = y_data_normalized ** y_scale
plt.scatter(times_myrs, y_data)
plt.xlabel('time [Myr]')
plt.ylabel('y data [normalized]')
plt.show()

# %%
import itertools as it

MIDI_A4 = 69

def str2midi(note_string):
    """Given a note string name (e.g. "Bb4"), returns its MIDI pitch number. (From audiolazy)
    """
    
    data = note_string.strip().lower()
    name2delta = {"c": -9, "d": -7, "e": -5, "f": -4, "g": -2, "a": 0, "b": 2}
    accident2delta = {"b": -1, "#": 1, "x": 2}
    accidents = list(it.takewhile(lambda el: el in accident2delta, data[1:]))
    octave_delta = int(data[len(accidents) + 1:]) - 4
    return (MIDI_A4 +
          name2delta[data[0]] + # Name
          sum(accident2delta[ac] for ac in accidents) + # Accident
          12 * octave_delta # Octave
         )

# %%
#from audiolazy import str2midi #import function to convert note names to midi numbers (could also use: midi2str, str2freq, freq2str,freq2midi,midi2freq) https://pypi.org/project/audiolazy/

# 4 octaves of major scale
note_names = ['C2','D2','E2','F2','G2','A2','B2',
             'C3','D3','E3','F3','G3','A3','B3',
             'C4','D4','E4','F4','G4','A4','B4',
             'C5','D5','E5','F5','G5','A5','B5']

#4 octaves of major pentatonic scale 
note_names = ['C2','D2','E2','G2','A2',
             'C3','D3','E3','G3','A3',
             'C4','D4','E4','G4','A4',
             'C5','D5','E5','G5','A5']

#custom note set (a voicing of a Cmaj13#11 chord, notes from C lydian)
note_names = ['C1','C2','G2',
             'C3','E3','G3','A3','B3',
             'D4','E4','G4','A4','B4',
             'D5','E5','G5','A5','B5',
             'D6','E6','F#6','G6','A6']

note_midis = [str2midi(n) for n in note_names] #make a list of midi note numbers 

n_notes = len(note_midis)
print('Resolution:',n_notes, 'notes')
# Out:
# Resolution: 23 notes

# %%
midi_data = []
print (note_midis)
#print(note_index)
# Choose a fixed note_index for all craters
fixed_note_index = 5  # You can choose any value within the valid range of note_midis

for i in range(len(Y_values)):
    midi_data.append(note_midis[fixed_note_index])

print(t_data)
print(midi_data)
plt.scatter(t_data, midi_data, s=50*y_data)
plt.xlabel('time [beats]')
plt.ylabel('midi note numbers')
plt.show()
# Out:
# [24, 36, 43, 48, 52, 55, 57, 59, 62, 64, 67, 69, 71, 74, 76, 79, 81, 83, 86, 88, 90, 91, 93]
#         x
# ------------------
#  4.987274473138929
#  5.096679638146258
#  5.110021731439832
#  5.104684894122404
#  5.099348056804972
#  5.099348056804972
#  5.067327032900387
#  5.080669126193965
#  5.256784757669179
#  3.794491332693184
#                ...
# 28.922989841815333
# 29.176489614393287
# 29.237863243543742
# 29.227189568908877
# 23.973073229898418
# 24.066467882953454
# 24.669530499823114
#  25.00308283216253
# 24.317299236872692
# 24.066467882953454
#   24.3359781674837
# Length = 12470 rows
# ...

# %%
midi_data = []
#print(y_data)
#print(note_midis)
#print(note_index)
for i in range(n_stars):
    note_index = round(map_value(y_data[i], 0, 1, n_notes-1, 0)) #notice choice of polarity: bigger craters are mapped to lower notes
                                                        #we round the result because it's a list index which must be an integer
    midi_data.append(note_midis[note_index])

plt.scatter(t_data, midi_data, s=50*y_data)
plt.xlabel('time [beats]')
plt.ylabel('midi note numbers')
plt.show()
#print (n_impacts)
print(note_index)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[24], line 6
#       2 #print(y_data)
#       3 #print(note_midis)
#       4 #print(note_index)
#       5 for i in range(n_stars):
# ----> 6     note_index = round(map_value(y_data[i], 0, 1, n_notes-1, 0)) #notice choice of polarity: bigger craters are mapped to lower notes
#       7                                                         #we round the result because it's a list index which must be an integer
#       8     midi_data.append(note_midis[note_index])
#
# File astropy\table\_column_mixins.pyx:74, in astropy.table._column_mixins._ColumnGetitemShim.__getitem__()
#
# File astropy\table\_column_mixins.pyx:57, in astropy.table._column_mixins.base_getitem()
#
# File astropy\table\_column_mixins.pyx:69, in astropy.table._column_mixins.column_getitem()
#
# ...

# %%
vel_min,vel_max = 35,127   #minimum and maximum note velocity

vel_data = []
for i in range(n_impacts):
    note_velocity = round(map_value(y_data[i], 0, 1, vel_min, vel_max)) #bigger craters will be louder
                                                                #we round here because note velocites are integers
    vel_data.append(note_velocity)
    
plt.scatter(t_data, midi_data, s=vel_data)
plt.xlabel('time [beats]')
plt.ylabel('midi note numbers')
plt.show()

# %% [markdown]
# ## Listen to MIDI file within jupyter

# %%
from midiutil import MIDIFile #import library to make midi file, https://midiutil.readthedocs.io/en/1.2.1/
    
#create midi file object, add tempo
my_midi_file = MIDIFile(1) #one track 
my_midi_file.addTempo(track=0, time=0, tempo=bpm) 

#add midi notes
for i in range(n_impacts):
    my_midi_file.addNote(track=0, channel=0, pitch=midi_data[i], time=t_data[i], duration=2, volume=vel_data[i])

#create and save the midi file itself
with open(filename + '.mid', "wb") as f:
    my_midi_file.writeFile(f)

# %%
import sys 
# !{sys.executable} -m pip install --quiet "pygame" 
#or use this if you installed python with anaconda
#conda install --yes --prefix {sys.prefix} pygame

import pygame #import library for playing midi files, https://pypi.org/project/pygame/

pygame.init()
pygame.mixer.music.load(filename + '.mid')
pygame.mixer.music.play()

# %%
pygame.mixer.music.stop()
